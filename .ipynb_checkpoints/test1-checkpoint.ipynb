# %%
test= read_csv("titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a540d5fd7cf> in <module>
# ----> 1 test= read_csv("titanic")
#
# NameError: name 'read_csv' is not defined

# %%
test

# %%
test= read_csv("titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2ecbb028f5ee> in <module>
# ----> 1 test= read_csv("titanic.csv")
#
# NameError: name 'read_csv' is not defined

# %%
test= pd.read_csv("titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2c5b999cd4ee> in <module>
# ----> 1 test= pd.read_csv("titanic.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
test=pd.read_csv("titanic.csv")

# %%
test
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
test.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 484         1       1    male  25.0      1      0  91.0792        C   First
# 149         0       2    male  42.0      0      0  13.0000        S  Second
# 396         0       3  female  31.0      0      0   7.8542        S   Third
# 709         1       3    male   NaN      1      1  15.2458        C   Third
# 839         1       1    male   NaN      0      0  29.7000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 484    man        True    B    Cherbourg   yes  False
# 149    man        True  NaN  Southampton    no   True
# 396  woman       False  NaN  Southampton    no   True
# 709    man        True  NaN    Cherbourg   yes  False
# 839    man        True    C    Cherbourg   yes   True

# %%
test.sample(5:5)
# Out:
#   File "<ipython-input-10-134e23b11488>", line 1
#     test.sample(5:5)
#                  ^
# SyntaxError: invalid syntax

# %%
test = pd.read_csv("tips.csv")

# %%
test
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
test.sample(100)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# 163       13.81  2.00    Male     No   Sun  Dinner     2
# 66        16.45  2.47  Female     No   Sat  Dinner     2
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 140       17.47  3.50  Female     No  Thur   Lunch     2
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3
# 106       20.49  4.06    Male    Yes   Sat  Dinner     2
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4
# 133       12.26  2.00  Female     No  Thur   Lunch     2
# 65        20.08  3.15    Male     No   Sat  Dinner     3
# 31        18.35  2.50    Male     No   Sat  Dinner     4
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# 32        15.06  3.00  Female     No   Sat  Dinner     2
# 173       31.85  3.18    Male    Yes   Sun  Dinner     2
# ...

# %%
test['Percentage'] =  (test['tip'] / test['total_bill'] ) * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e6881ad87bf8> in <module>
# ----> 1 test['Percentage'] =  (test['tip'] / dfObj['total_bill'] ) * 100
#
# NameError: name 'dfObj' is not defined

# %%
test['Percentage'] =  (test['tip'] / test['total_bill'] ) * 100

# %%
test
# Out:
#      total_bill   tip     sex smoker   day    time  size  Percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2    5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3   16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3   16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2   13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765
# 5         25.29  4.71    Male     No   Sun  Dinner     4   18.623962
# 6          8.77  2.00    Male     No   Sun  Dinner     2   22.805017
# 7         26.88  3.12    Male     No   Sun  Dinner     4   11.607143
# 8         15.04  1.96    Male     No   Sun  Dinner     2   13.031915
# 9         14.78  3.23    Male     No   Sun  Dinner     2   21.853857
# 10        10.27  1.71    Male     No   Sun  Dinner     2   16.650438
# 11        35.26  5.00  Female     No   Sun  Dinner     4   14.180374
# 12        15.42  1.57    Male     No   Sun  Dinner     2   10.181582
# ...

# %%
dtest=test.sample(50)

# %%
dtest
# Out:
#      total_bill   tip     sex smoker   day    time  size  Percentage
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2   71.034483
# 165       24.52  3.48    Male     No   Sun  Dinner     3   14.192496
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765
# 227       20.45  3.00    Male     No   Sat  Dinner     4   14.669927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352
# 48        28.55  2.05    Male     No   Sun  Dinner     3    7.180385
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2   15.384615
# 143       27.05  5.00  Female     No  Thur   Lunch     6   18.484288
# 124       12.48  2.52  Female     No  Thur   Lunch     2   20.192308
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2   24.217745
# 193       15.48  2.02    Male    Yes  Thur   Lunch     2   13.049096
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2   19.505852
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2   13.812155
# ...

# %%
dtest['Percentage'] =  (dtest['tip'] / dtest['total_bill'] ) * 100

# %%
dtest
# Out:
#      total_bill   tip     sex smoker   day    time  size  Percentage
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2   71.034483
# 165       24.52  3.48    Male     No   Sun  Dinner     3   14.192496
# 4         24.59  3.61  Female     No   Sun  Dinner     4   14.680765
# 227       20.45  3.00    Male     No   Sat  Dinner     4   14.669927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    7.358352
# 48        28.55  2.05    Male     No   Sun  Dinner     3    7.180385
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2   15.384615
# 143       27.05  5.00  Female     No  Thur   Lunch     6   18.484288
# 124       12.48  2.52  Female     No  Thur   Lunch     2   20.192308
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2   24.217745
# 193       15.48  2.02    Male    Yes  Thur   Lunch     2   13.049096
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2   19.505852
# 177       14.48  2.00    Male    Yes   Sun  Dinner     2   13.812155
# ...

# %%
correlation= dtest['tip'].corr(dtest['total_bill'])

# %%
correlation
# Out:
# 0.637375978680283

# %%
dtest[(dtest.smoker == "Yes") & (dtest.sex=="Female") & (dtest.time=="Lunch")]
# Out:
#      total_bill  tip     sex smoker   day   time  size  Percentage
# 198       13.00  2.0  Female    Yes  Thur  Lunch     2   15.384615
# 197       43.11  5.0  Female    Yes  Thur  Lunch     4   11.598237

# %%
X_Men =dtest[(dtest.sex=="Male")]
Y_Women =dtest[(dtest.sex=="Female")]
Z_Smoker= dtest[(dtest.smoker=="Yes")]

# %%
plt.plot(X_Men, Y_Women)
plt.plot(X_Men,Z_Smoker)

plt.title("Smokers per Gender",color= 'blue')
plt.xlabel("Men Smokers",color='green')
plt.ylabel("Female Smokers ",color ='black')
plt.legend(["Male","female"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-2c7398e8b227> in <module>
# ----> 1 plt.plot(X_Men, Y_Women)
#       2 plt.plot(X_Men,Z_Smoker)
#       3
#       4 plt.title("Smokers per Gender",color= 'blue')
#       5 plt.xlabel("Men Smokers",color='green')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
plt.plot(X_Men, Y_Women)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-9d4f6ddf1b67> in <module>
#       1
# ----> 2 plt.plot(X_Men, Y_Women)
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
x=dtest['sex']
y=dtest[(dtest.smoker=="Yes")]

plt.plot(x, percentage)
plt.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4841e3d7427f> in <module>
#       2 y=dtest[(dtest.smoker=="Yes")]
#       3
# ----> 4 plt.plot(x,y)
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
fsmoker = dtest[dtest.smoker == "Yes"]
fsex= fsmoker[fsmoker.sex == "Female"]

msmoker = dtest[dtest.smoker == "Yes" ]
msex = msmoker[msmoker.sex == "Male"]

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ae02d6a4a9b3> in <module>
# ----> 1 plt.plot(msex.sex, msex.percentage)
#       2 plt.plot(fsex.sex, fsex.percentage)
#       3
#       4 plt.title('percentage tips per gender', color= 'blue', fontsize = 'large')
#       5 plt.legend(['Males','Females'], fontsize = 'large')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'percentage'

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
style.use('yellow_background')
plt.show()

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
style.use('dark_background')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-789549503748> in <module>
#       6 plt.xlabel('Gender', fontsize = 'x-large')
#       7 plt.ylabel('Percentage tip offered', fontsize = 'x-large')
# ----> 8 style.use('yellow_background')
#       9 plt.show()
#
# NameError: name 'style' is not defined

# %%
import matplotlib.style as style

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
style.use('dark_background')
plt.show()

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
 plt.style.use(['dark_background', 'presentation'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-358322c47114> in <module>
#       6 plt.xlabel('Gender', fontsize = 'x-large')
#       7 plt.ylabel('Percentage tip offered', fontsize = 'x-large')
# ----> 8 style.use(color='dark')
#       9 plt.show()
#
# TypeError: use() got an unexpected keyword argument 'color'

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
plt.style.use(['dark_background', 'presentation'])
plt.show()
# Out:
#   File "<ipython-input-35-34a5803c5b93>", line 8
#     plt.style.use(['dark_background', 'presentation'])
#     ^
# IndentationError: unexpected indent

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
plt.style.use(['dark_background', 'presentation'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\style\core.py in use(style)
#     110             try:
# --> 111                 rc = rc_params_from_file(style, use_default_template=False)
#     112                 _apply_style(rc)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#    1069     """
# -> 1070     config_from_file = _rc_params_in_file(fname, fail_on_error)
#    1071
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, fail_on_error)
#     985     rc_temp = {}
# --> 986     with _open_file_or_url(fname) as fd:
#     987         try:
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#
# ...

# %%
plt.plot(msex.sex, msex.Percentage)
plt.plot(fsex.sex, fsex.Percentage)

plt.title('Percentage tips per gender', color= 'blue', fontsize = 'large')
plt.legend(['Males','Females'], fontsize = 'large')
plt.xlabel('Gender', fontsize = 'x-large')
plt.ylabel('Percentage tip offered', fontsize = 'x-large')
plt.style.use(['dark_background'])
plt.show()
