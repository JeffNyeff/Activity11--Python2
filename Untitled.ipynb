# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
datam = pd.read_csv("titanic.csv")

# %%
datam
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
datam[:50]
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0          0       3    male  22.0      1      0    7.2500        S   Third
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 2          1       3  female  26.0      0      0    7.9250        S   Third
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 4          0       3    male  35.0      0      0    8.0500        S   Third
# 5          0       3    male   NaN      0      0    8.4583        Q   Third
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 7          0       3    male   2.0      3      1   21.0750        S   Third
# 8          1       3  female  27.0      0      2   11.1333        S   Third
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
x =data[(data.smoker == "Yes")
y=data[(data.smoker == "No")
       
plt.plot(x, y)
plt.title("Test Plot")
plt.xlabel("X")
plt.ylabel('Y')
plt.show()
# Out:
#   File "<ipython-input-6-92b552d69638>", line 2
#     y=data[(data.smoker == "No")
#     ^
# SyntaxError: invalid syntax

# %%
datam = pd.read_csv('titanic.csv', names=['Col_a', 'Col_b'])

# %%
datam
# Out:
#                                                                                                    Col_a  \
# survived pclass sex    age  sibsp parch fare    embarked class  who   adult_male deck embark_town  alive
# 0        3      male   22.0 1     0     7.25    S        Third  man   True       NaN  Southampton     no
# 1        1      female 38.0 1     0     71.2833 C        First  woman False      C    Cherbourg      yes
#          3      female 26.0 0     0     7.925   S        Third  woman False      NaN  Southampton    yes
#          1      female 35.0 1     0     53.1    S        First  woman False      C    Southampton    yes
# 0        3      male   35.0 0     0     8.05    S        Third  man   True       NaN  Southampton     no
#                        NaN  0     0     8.4583  Q        Third  man   True       NaN  Queenstown      no
#          1      male   54.0 0     0     51.8625 S        First  man   True       E    Southampton     no
# ...

# %%
data['sex'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-16164fd711c3> in <module>
# ----> 1 surveys_df['sex'].describe()
#
# NameError: name 'surveys_df' is not defined

# %%
data['sex'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cd7703b5a2f2> in <module>
# ----> 1 data['sex'].describe()
#
# NameError: name 'data' is not defined

# %%
datam['sex'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sex'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-7d0031ee420d> in <module>
# ----> 1 datam['sex'].describe()
#
# ...

# %%
datam.sample(10)
